# %% [markdown]
# <a href="https://colab.research.google.com/github/Haikoo96/Kpop-Trend-Analysis/blob/master/scraping%20and%20preprocess/K_IDOL_db_scrape_tojson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Objective**
# 1. scrape all the K-Idol groups and members' name as key-value pairs
# 2. These key-value pairs will be used as the ground truth to match the keywords extracted by the NER model.

# %%
import requests
from bs4 import BeautifulSoup
import string
import pandas as pd
import numpy as np
import json
import re

# %%
url = 'https://kpopping.com/profiles/the-groups'

# Send a GET request to the page
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    elements = soup.find_all(class_='items')
else:
    print("Failed to retrieve the webpage")

# %% [markdown]
# ## **First obtain the raw list of k-idol groups and members**

# %%
# Raw List of K-IDOL groups and members
kidol_lst = [element.parent.text.split('\n') for element in elements]

# first remove empty strings if any
for lst in kidol_lst:
  for val in lst:
    if val == '' or val == r'^$':
      lst.remove(val)

kidol_lst[1]
# Out:
# ['A',
#  'A SIX',
#  '( Park Boeun',
#  ', Won Jimin',
#  ', J-Min',
#  ', Ling Qi',
#  ', Lee Han Bin',
#  ', Youngseo',
#  ')',
#  'A Train To Autumn',
#  '( Somi',
#  ', Lee A Young',
#  ', Subin',
#  ', Jihyeon',
#  ')',
#  'A_Label',
#  '( Seunga',
#  ', Hyeni',
#  ', Rina',
#  ')',
#  'A-Daily',
#  '( MUU',
#  ', NoA',
#  ', ChaeE',
#  ', Yunseol',
#  ', Youngbi',
#  ', Jei',
#  ', Cho Jisun',
#  ', Sena',
#  ')',
#  'A-DEAN',
#  '( Jimin',
#  ', Yuki',
#  ', Joohyun',
#  ', Haru',
#  ')',
#  'A-Fati',
#  '( Jiyun',
#  ', Hyoi',
#  ')',
#  'A-FEEL',
#  '( Haeseon',
#  ', Mini',
#  ', Jini',
#  ', Ssun',
#  ', Mina',
#  ')',
#  'A-Jax',
#  '( Jaehyung',
#  ', Seungjin',
#  ', Jihu',
#  ', Sungmin',
#  ', Joonghee',
#  ', Yunyoung',
#  ', Dowoo',
#  ', Seungyub',
#  ')',
#  'A-Plus',
#  '( Dayoung',
#  ', Hyoeun',
#  ', Yeonhee',
#  ')',
#  'A-plus',
#  '( Song Hwanhee',
#  ', Lee Heeju',
#  ', Byun Subin',
#  ', Kim Jiyun',
#  ', Kim Jamin',
#  ', An Soyeon',
#  ', Jihyun',
#  ')',
#  'A-Prince',
#  '( Minhyuk',
#  ', J.Vin',
#  ', Sun',
#  ', J.Jun',
#  ')',
#  'A-seed',
#  '( Jihyun',
#  ', Mini',
#  ', Soyeon',
#  ', Soly',
#  ')',
#  'A:FACT',
#  '( Bawool',
#  ', Kwon Taeeun',
#  ', Jeon Sejin',
#  ', Hoseong',
#  ', Wondae',
#  ')',
#  'A.C.E',
#  '( Park Junhee',
#  ', Wow',
#  ', Kang Yuchan',
#  ', Kim Byeongkwan',
#  ', Lee Donghun',
#  ')',
#  'A.Cian',
#  '( Euijin',
#  ', Sehee',
#  ', Jin.O',
#  ', Sanghyeon',
#  ', Hyeok Jin',
#  ', Jungsang',
#  ')',
#  'A.De',
#  '( Haeyoung',
#  ', Choyoon',
#  ', Rachel',
#  ', Jiseo',
#  ', Yeorin',
#  ', Heo Jay',
#  ', Miso',
#  ')',
#  'A.H.H.A',
#  '( Kangbin',
#  ', Yeojin',
#  ', Byeolha',
#  ', Eun A',
#  ')',
#  'A.iRiD',
#  '( Bell',
#  ', Echae',
#  ', Day',
#  ', Ari',
#  ')',
#  'A.KOR',
#  '( Minju',
#  ', Taehee',
#  ', Daya',
#  ', Kemy',
#  ', Jiyoung',
#  ')',
#  'A.KOR Black',
#  '( Minju',
#  ', Kemy',
#  ')',
#  'A.S. BLUE',
#  '( Raina',
#  ', Park Soo-ah',
#  ', E Young',
#  ', Jooyeon',
#  ')',
#  'A.S. RED',
#  '( Nana',
#  ', UEE',
#  ', Kahi',
#  ', Jung-A',
#  ')',
#  'A.sia',
#  '( Yumi',
#  ', Zoo.Y',
#  ', Suen',
#  ', Sion',
#  ')',
#  'A.SOME',
#  '( Lee Se Rim',
#  ', Kim Eun Ji',
#  ', Han Mi Na',
#  ', Seo Yoon Kyung',
#  ', Park Hyun Ju',
#  ', Moon Mi Kyeong',
#  ')',
#  'A+B',
#  '( by me',
#  ', Able',
#  ')',
#  'AA',
#  '( Jinhong',
#  ', Hoik',
#  ', Joowon',
#  ', Woosang',
#  ', Aoora',
#  ', Kimchi',
#  ')',
#  'AB6IX',
#  '( Daehwi',
#  ', Woojin',
#  ', Donghyun',
#  ', Woong',
#  ', Lim Young Min',
#  ')',
#  'ABLUE',
#  '( You',
#  ', WinL',
#  ', Sukjun',
#  ', Seongsoo',
#  ', Gyuchan',
#  ', On',
#  ', Wonjun',
#  ')',
#  'AboutU',
#  '( Victor Han',
#  ', Yi Soo',
#  ', NeoN',
#  ', Do Yoon',
#  ')',
#  'ABRY',
#  '( Yeji',
#  ', Soeun',
#  ', SeolA',
#  ', Gayun',
#  ')',
#  'ACE',
#  '( Pichu',
#  ', Aria',
#  ', Seora',
#  ', Youzin',
#  ')',
#  'Acid Angel from Asia',
#  '( Kim Yooyeon',
#  ', Kim Nakyoung',
#  ', Gong Yubin',
#  ', Jeong Hyerin',
#  ')',
#  'ACID EYES',
#  '( Kim Yooyeon',
#  ', Kim Nakyoung',
#  ', Yoon Seoyeon',
#  ', Kim Chaeyeon',
#  ', Lee Jiwoo',
#  ', Gong Yubin',
#  ', Kim Soomin',
#  ', Jeong Hyerin',
#  ')',
#  'Adios Audio',
#  'ADYA',
#  '( Yeonsu',
#  ', Chaeeun',
#  ', Seowon',
#  ', Seungchae',
#  ', Sena',
#  ')',
#  'aespa',
#  '( Karina',
#  ', Winter',
#  ', NingNing',
#  ', Giselle',
#  ')',
#  'Aesther',
#  '( Mika',
#  ', Karin',
#  ', Ellie',
#  ', Eris',
#  ', Arisa',
#  ')',
#  'AFOS',
#  '( Baek Seung Heon',
#  ', Hu',
#  ', Jooen',
#  ', Aknow',
#  ', Zett',
#  ')',
#  'After School',
#  '( Nana',
#  ', UEE',
#  ', Raina',
#  ', Lee Ga Eun',
#  ', Kahi',
#  ', Park Soo-ah',
#  ', E Young',
#  ', Jooyeon',
#  ', Jung-A',
#  ', Bekah',
#  ', So-young',
#  ')',
#  'AGirls',
#  '( Areum',
#  ', Hye Ji',
#  ', Yeon Ju',
#  ', Jane',
#  ', Jinsil',
#  ')',
#  'Aila',
#  '( Yena',
#  ', Shiyeon',
#  ', Rahee',
#  ', Kelly',
#  ')',
#  'AIMERS',
#  '( Yoel',
#  ', Seunghyun',
#  ', Wooyoung',
#  ', Doryun',
#  ', Seunghwan',
#  ', Eunjun',
#  ')',
#  'AiRiSU',
#  '( Nicky',
#  ', Ina',
#  ', HanU',
#  ', Eun Ji',
#  ')',
#  'AKMU',
#  '( Suhyun',
#  ', Chanhyuk',
#  ')',
#  'AL',
#  '( Sion',
#  ', Lee Jaeyoung',
#  ', Kang Jihyun',
#  ', Jung Hye Min',
#  ')',
#  'ALICE',
#  '( Sohee',
#  ', Yukyung',
#  ', Do-A',
#  ', Yeonje',
#  ', Karin',
#  ', EJ',
#  ', Chaejeong',
#  ')',
#  'Alice White',
#  '( Yehana',
#  ', Minyeong',
#  ', Arlene',
#  ', Sieun',
#  ', Eunjo',
#  ')',
#  'ALiKE',
#  '( Ga Hyeon',
#  ', Wook Jin',
#  ', Sung A',
#  ')',
#  'All-Star',
#  '( Jun.H',
#  ', KNOA',
#  ', HUGH',
#  ')',
#  '',
#  'ALL(H)OURS',
#  '( ON:N',
#  ', Masami',
#  ', Xayden',
#  ', Hyunbin',
#  ', Youmin',
#  ', Minje',
#  ', Kunho',
#  ')',
#  '',
#  '',
#  'ALLS-GIRL',
#  '( Chaehyeon',
#  ', Hyeongshin',
#  ', Yujin',
#  ', YoeSLee',
#  ', Karam',
#  ', Ria',
#  ')',
#  '',
#  '',
#  'Almeng',
#  '( Lee Hae Yong',
#  ', Choi Rin',
#  ')',
#  '',
#  '',
#  'AlphaBat',
#  '( E:psilon',
#  ', J:eta',
#  ', I:ota',
#  ', H:eta',
#  ', F:ie',
#  ', D:elta',
#  ', C:ode',
#  ', G:amma',
#  ', K:appa',
#  ', L:ambda',
#  ', B:eta',
#  ')',
#  '',
#  '',
#  'Ambition',
#  '( Taeho',
#  ', Daehyun',
#  ', Rookie',
#  ', Ryu',
#  ', Kyle',
#  ')',
#  '',
#  '',
#  'AMOR',
#  '( Suri',
#  ', Eunsol',
#  ', Jei',
#  ', Eseul',
#  ', Doyeon',
#  ', Mari',
#  ')',
#  '',
#  '',
#  'Amourette',
#  '( Hoody',
#  ', Nam Seri',
#  ', Nieah',
#  ', KittiB',
#  ')',
#  '',
#  '',
#  'AMPERS&ONE',
#  '( Kamden',
#  ', Mackiah',
#  ', Brian',
#  ', Jiho',
#  ', Seungmo',
#  ', Siyun',
#  ', Kyrell',
#  ')',
#  '',
#  '',
#  'An Old Moon',
#  '( Kim Sunbin',
#  ', Lee Jun Mo',
#  ', Lee Ji Nam',
#  ', Go Chang Young',
#  ', Kim Kyoungsup',
#  ', Choi Goeun',
#  ')',
#  '',
#  '',
#  'ANDS',
#  '( DJ Ca$h',
#  ', Nayom',
#  ', Lydia',
#  ', Rai',
#  ', Yeoul',
#  ')',
#  '',
#  '',
#  'Another Level',
#  '( Rossi',
#  ', Nara',
#  ', Mari',
#  ', Benny',
#  ', Jini',
#  ', Ellie',
#  ')',
#  '',
#  '',
#  'ANS',
#  '( Bian',
#  ', J',
#  ', YoeSLee',
#  ', Haena',
#  ', Dalyn',
#  ', Lina',
#  ', Dam I',
#  ', Rozu',
#  ')',
#  '',
#  '',
#  'ANTARES',
#  '( Seunghee',
#  ', Hwi',
#  ')',
#  '',
#  '',
#  'AOA',
#  '( Seolhyun',
#  ', ChoA',
#  ', Jimin',
#  ', Hyejeong',
#  ', Mina',
#  ', Yuna',
#  ', Im Do Hwa',
#  ', Youkyung',
#  ')',
#  '',
#  '',
#  'AOA Black',
#  '( ChoA',
#  ', Jimin',
#  ', Mina',
#  ', Yuna',
#  ', Youkyung',
#  ')',
#  '',
#  '',
#  'AOA CREAM',
#  '( Hyejeong',
#  ', Yuna',
#  ', Im Do Hwa',
#  ')',
#  '',
#  '',
#  'API',
#  '( Saebyeok',
#  ', Son Seoah',
#  ', Dany',
#  ', Haru',
#  ', Heejoo',
#  ', Cheong Eum',
#  ')',
#  '',
#  '',
#  'Apink',
#  '( Naeun',
#  ', Chorong',
#  ', Eunji',
#  ', Hayoung',
#  ', Bomi',
#  ', Namjoo',
#  ', Yookyung',
#  ')',
#  '',
#  '',
#  'Apink JooJiRong',
#  '( Chorong',
#  ', Eunji',
#  ', Namjoo',
#  ')',
#  '',
#  '',
#  'Apink Y.O.S',
#  '( Naeun',
#  ', Hayoung',
#  ', Bomi',
#  ')',
#  '',
#  '',
#  'Apple.B',
#  '( Haeun',
#  ', Yuji',
#  ', Yurim',
#  ', Sandy',
#  ', Hyunmin',
#  ')',
#  '',
#  '',
#  'APRIL',
#  '( Somin',
#  ', Naeun',
#  ', Chaewon',
#  ', Jinsol',
#  ', Rachel',
#  ', Yena',
#  ', Chaekyung',
#  ', Hyunjoo',
#  ')',
#  '',
#  '',
#  'APRIL KISS',
#  '( Sara',
#  ', Coo.G',
#  ', Julie',
#  ', Haezn',
#  ', LIZE',
#  ', Sumin',
#  ')',
#  '',
#  '',
#  'AQUA',
#  '( Hyerim',
#  ', Seungji',
#  ', Sihyun',
#  ', Haesol',
#  ', SuA',
#  ', Hyeonju',
#  ')',
#  '',
#  '',
#  'AR3NA',
#  '',
#  '',
#  'AREAL',
#  '( Segye',
#  ', Hyebin',
#  ', Dabi',
#  ', Areum',
#  ')',
#  '',
#  '',
#  'ARGON',
#  '( Gon',
#  ', WIN',
#  ', Jaeun',
#  ', Yeoun',
#  ', Roel',
#  ', Haneul',
#  ', Kain',
#  ')',
#  '',
#  '',
#  'Aria',
#  '( Kim Chaeyeon',
#  ', Lee Jiwoo',
#  ', Seo Dahyun',
#  ', Nien',
#  ', Kaede',
#  ')',
#  '',
#  '',
#  'ARIAZ',
#  '( Dawon',
#  ', Yeori',
#  ', Jueun',
#  ', Jang HyoGyung',
#  ', Sihyeon',
#  ', Yunji',
#  ')',
#  '',
#  '',
#  'ARTBEAT v',
#  '( Seyoung',
#  ', Haeun',
#  ', Gaeun',
#  ', Yubin',
#  ', Yoojin',
#  ', Damhee',
#  ', Sieun',
#  ')',
#  '',
#  '',
#  'ARTMS',
#  '( HeeJin',
#  ', JinSoul',
#  ', Kim Lip',
#  ', HaSeul',
#  ', Choerry',
#  ')',
#  '',
#  '',
#  'As One',
#  '( Kira Chan',
#  ', Chloe',
#  ', Oli',
#  ', Nata',
#  ', Elfa',
#  ', Shin',
#  ')',
#  '',
#  '',
#  'As One (1999)',
#  '( Min',
#  ', Crystal',
#  ')',
#  '',
#  '',
#  'ASC2NT',
#  '( Jay',
#  ', Kyle',
#  ', Reon',
#  ', Injun',
#  ', Karam',
#  ')',
#  '',
#  '',
#  'ASHA',
#  '( Hyuna',
#  ', Yoha',
#  ', Nara',
#  ', Daae',
#  ')',
#  '',
#  '',
#  'Ashatree',
#  '( Bang Taeyeon',
#  ', Moon Jiwon',
#  ')',
#  '',
#  '',
#  'Asome.D',
#  '( Nahyun',
#  ', Dada',
#  ', Zi.L',
#  ')',
#  '',
#  '',
#  'ASTRO',
#  '( Cha Eunwoo',
#  ', Moonbin',
#  ', MJ',
#  ', Rocky',
#  ', Jinjin',
#  ', Sanha',
#  ')',
#  '',
#  '',
#  'ATBO',
#  '( Rakwon',
#  ', Wonbin',
#  ', Hyunjun',
#  ', Seunghwan',
#  ', Yeonkyu',
#  ', Junseok',
#  ', Junmin',
#  ')',
#  '',
#  '',
#  'ATEEZ',
#  '( San',
#  ', Seonghwa',
#  ', Mingi',
#  ', Hongjoong',
#  ', Wooyoung',
#  ', Yeosang',
#  ', Yunho',
#  ', Jongho',
#  ')',
#  '',
#  '',
#  'ATT',
#  '( Yujeong',
#  ', A Young',
#  ', Sebi',
#  ', Seyeon',
#  ', Seohee',
#  ')',
#  '',
#  '',
#  'Awe5ome Baby',
#  '( Yechan',
#  ', Sumin',
#  ', June',
#  ', Lina',
#  ', Yi Chaebin',
#  ')',
#  '',
#  '',
#  'AWEEK',
#  '( Aiden',
#  ', Di1e',
#  ', Jini',
#  ', Yoonsang',
#  ', Jingyu',
#  ', Hyeon',
#  ', Chawon',
#  ')',
#  '',
#  '',
#  'AWESOME',
#  '( BeatYou',
#  ', Youri',
#  ', Chealin',
#  ', Bada',
#  ')',
#  '',
#  '',
#  'AxisB',
#  '( Daeyoung',
#  ', Junghoon',
#  ')',
#  '',
#  '',
#  'AZER',
#  '( Yujin',
#  ', Soyeon',
#  ', Minseo',
#  ', Mijeong',
#  ', Jaein',
#  ', Juyeon',
#  ', Youkyung',
#  ')',
#  '',
#  '',
#  'Azer Blossom',
#  '( Jihyun',
#  ', Yoo Minha',
#  ', Minkyung',
#  ', Seohyun',
#  ', Siwoo',
#  ', Yeum',
#  ', Yejin',
#  ', Jihyun',
#  ')',
#  '',
#  '',
#  'AZM',
#  '( Delta',
#  ', Suhyun',
#  ', Seoyeon',
#  ', Yejin',
#  ', Eunji',
#  ', Sia',
#  ', Lok',
#  ')',
#  '',
#  '',
#  '']

# %% [markdown]
# ##**Processing the raw "kidol_lst"**
# - the list is alphabetically ordered by the first element of the nested list except for the very first one.
# - Basically, all the idol groups in the nested list begin with the same letter.
# - Given this condition, it is wise to organize them into key-value pairs where keys are the alphabet and values will be the group's name under which the members' names will be included.

# %%
# putting the raw list to two key-value pairs:
# one for special characters and the other for the alphabetically ordered one
def organize_idol_lst(lst, tar_str, letter_to_avoid):
    if tar_str not in ['()', '{}', '[]']:
        print('Only a pair of parentheses, brackets, or braces is accepted such as (), {}, []')
        return {}, {}  # Early return if tar_str is not valid

    print('Ready to organize')
    special_char_dict = {'#': {}}
    alpha_order_dict = {letter: {} for letter in string.ascii_uppercase}

    for i, sub_lst in enumerate(lst):
        idx_lst = []

        # Simplify the loop by directly collecting the necessary pairs of indices and keys
        for idx, element in enumerate(sub_lst):
            if element.startswith(tar_str[0]) and not sub_lst[idx-1].startswith(letter_to_avoid):
                try:
                    end_idx = sub_lst.index(tar_str[1], idx)  # Find the matching end index
                    name_key = sub_lst[idx-1].strip()  # Extract the key, assuming it's directly before the start symbol
                    name_value = sub_lst[idx:end_idx+1]  # Include end_idx in the slice

                    # Decide on which dictionary to use
                    target_dict = special_char_dict['#'] if i == 0 else alpha_order_dict.get(name_key[0].upper(), {})
                    target_dict[name_key] = name_value
                except ValueError:
                    print(f"Matching {tar_str[1]} not found for {element} at index {idx}.")
                except IndexError:
                    print(f"No key found before {element} at index {idx}.")

    return special_char_dict, alpha_order_dict

# %%
special_char_idol, normal_char_idol = organize_idol_lst(kidol_lst, '()', '(G)')
# Out:
# Ready to organize

# %%
len(normal_char_idol['B'].keys())
# Out:
# 109

# %%
count = 0

for key in normal_char_idol['B'].keys():
  if key in kidol_lst[2]:
    count += 1

print(count)
# Out:
# 109

# %%
normal_char_idol['B']
# Out:
# {'B.A.P': ['( Youngjae',
#   ', Bang Yongguk',
#   ', Jongup',
#   ', Daehyun',
#   ', Zelo',
#   ', Himchan',
#   ')'],
#  'B.D.U': ['( Seunghun', ', Jay Chang', ', Kim Minseo', ', Bitsaeon', ')'],
#  'B.Dolls': ['( Yewon',
#   ', Taeyoon',
#   ', Seungjoo',
#   ', Seo I',
#   ', Hayeon',
#   ', Geunyoung',
#   ')'],
#  'B.I.G': ['( Heedo',
#   ', Benji',
#   ', Gunmin',
#   ', Minpyo',
#   ', Jinseok',
#   ', J-Hoon',
#   ')'],
#  'B.O.Y': ['( Kook Heon', ', Yuvin', ')'],
#  'B1A4': ['( Jinyoung', ', CNU', ', Baro', ', Sandeul', ', Gongchan', ')'],
#  'B2ST (BEAST)': ['( Gikwang',
#   ', Yoseop',
#   ', Dongwoon',
#   ', Doojoon',
#   ', Yong Jun Hyung',
#   ', Hyunseung',
#   ')'],
#  'BaBa': ['( Hayun',
#   ', Youzin',
#   ', Jin Dozin',
#   ', Seungha',
#   ', Kim Hye-won',
#   ', Serin',
#   ', Somi',
#   ', Bimby',
#   ', Byulha',
#   ', Dayul',
#   ', Hyoah',
#   ', Seoae',
#   ', Yera',
#   ', Sooreem',
#   ', Seyul',
#   ', Chaeha',
#   ', Starlight',
#   ', Pureum',
#   ', Roha',
#   ', Johwa',
#   ', Haena',
#   ')'],
#  'BABY BLUE': ['( Jinaon', ', Do Ayun', ')'],
#  'Baby Boo': ['( Han Leeseul',
#   ', Dayul',
#   ', Jieun',
#   ', Sehee',
#   ', Chaei',
#   ', Soli',
#   ', Hyogang',
#   ', Ha One',
#   ', Roori',
#   ', Hajin',
#   ', Daon',
#   ', Bada',
#   ')'],
#  'BABY V.O.X': ['( Lee Hee Jin',
#   ', Kim E-Z',
#   ', Jeong Hyeon Jeon',
#   ', Lee Gai',
#   ', Yoon Eun Hye',
#   ', Kan Miyoun',
#   ', Jung Si Woon',
#   ', Cha Yu Mi',
#   ', Shim Eun Jin',
#   ')'],
#  'Baby V.O.X Re.V': ['( Yang Eun Ji',
#   ', Oh Min Jin',
#   ', Myung Sa Rang',
#   ', Han Ae Ri',
#   ', Park So Ri',
#   ', Hwang Yun Kyung',
#   ', An Jinkyoung',
#   ')'],
#  'BABYMONSTER': ['( Chiquita',
#   ', Ahyeon',
#   ', Ruka',
#   ', Asa',
#   ', Rora',
#   ', Pharita',
#   ', Rami',
#   ')'],
#  'BABYS': ['( Seoyu', ', Yeseo', ', Suyeon', ')'],
#  'BADKIZ': ['( Han Jung A',
#   ', Rosy',
#   ', Hana',
#   ', Yoomin',
#   ', Jain',
#   ', Jina Yu',
#   ', Somin',
#   ', Lohee',
#   ', Kang Han Kyoung',
#   ', Na Mi Ri',
#   ', Eunsom',
#   ', Yeonji',
#   ', Sihyun',
#   ', Seoeun',
#   ', Haneul',
#   ', Bollo',
#   ', Yousi',
#   ', Han Na Hwi',
#   ', Yuki',
#   ', Yeunji',
#   ', Hayoung',
#   ', NIKA',
#   ')'],
#  'BAE173': ['( Hangyul',
#   ', Dohyon',
#   ', Muzin',
#   ', J-Min',
#   ', Doha',
#   ', Bit',
#   ', Youngseo',
#   ', Junseo',
#   ', Yoojun',
#   ')'],
#  'Balming Tiger': ['( Omega Sapien', ', Mudd the Student', ', sogumm', ')'],
#  'Bambino': ['( Eunsol',
#   ', Hadam',
#   ', Minhee',
#   ', Nina',
#   ', Eun A',
#   ', Seo A',
#   ', Dahee',
#   ')'],
#  'Bamsem & hyeminsong': ['( hyeminsong', ', Bamsem', ')'],
#  'Bandage': ['( HYEONGBIN', ', KYOUNGYOON', ', HYUNBIN', ', CHANSOL', ')'],
#  'Bay.B': ['( Miel', ', Seol.A', ', Seorin', ')'],
#  'BB Ahn': ['( Yoo Sungeun', ', Bling Bling', ', Americano', ')'],
#  'BB GIRLS': ['( Yuna',
#   ', Eunji',
#   ', Yujeong',
#   ', Minyoung',
#   ', Lee Hayun',
#   ', Yujin',
#   ', Yejin',
#   ', Park Seoa',
#   ', Jainros',
#   ', Park Eun Young',
#   ')'],
#  'BBde Girl': ['( Lyulin',
#   ', Christine',
#   ', Li-V',
#   ', Nanah',
#   ', E-Sea',
#   ', Sonhana',
#   ')'],
#  'Bbeum': ['( Ingyoung', ', Chohee', ')'],
#  'Bbi-Ddack': ['( XXNANA', ', LunaTune', ')'],
#  'BBURECTOR': ['( Yerim', ', Sara', ', Siyeon', ', Bbujju', ')'],
#  'BCHCS': ['( Chaeyeon', ', Yebin', ', Somyi', ', Huihyeon', ', Eunice', ')'],
#  'BDC': ['( Junghwan', ', Sihun', ', Seongjun', ')'],
#  'Be.A': ['( BomB',
#   ', Milly',
#   ', Loki',
#   ', Yeongkyun',
#   ', ATO',
#   ', Hongkyu',
#   ')'],
#  'Beatwin': ['( Yoonhoo',
#   ', Seongho',
#   ', Jungha',
#   ', Sanggyu',
#   ', Youngjo',
#   ', Sunhyeok',
#   ')'],
#  'Beautiful Days': ['( Joonghyun', ', Heungsun', ', Oh Heejung', ')'],
#  'Beauty Box': ['( Jerin',
#   ', Rina',
#   ', Anh',
#   ', Sara',
#   ', Via',
#   ', Chaeeun',
#   ', Sori',
#   ', Gahyun',
#   ')'],
#  'BeBe Mignon': ['( Ben', ', Gaeul', ', Hae Geum', ')'],
#  'BEBEHEAL': ['( Ayumu', ', Lyn', ', RaHee', ', JungHwa', ')'],
#  'Bebop': ['( A-Yeon', ', Jang Hyeri', ', Ju Woo', ')'],
#  'BECZ': ['( You', ', WinL', ', Seongsoo', ', KIRI', ', HUGH', ')'],
#  'Bella': ['( Lucy', ', Kani', ', Bohye', ')'],
#  'BELLA4': ['( Hyojung', ', Boreum', ', Wonji', ', Lina', ')'],
#  'BellaMafia': ['( Sujin Kim', ', Hyun Jyu-ni', ')'],
#  'Berry Good': ['( Shin Jee Won',
#   ', Kim Nayeon',
#   ', Sehyung',
#   ', ISHA',
#   ', Daye',
#   ', E.SO',
#   ', Taeha',
#   ', Iera',
#   ', Subin',
#   ')'],
#  'Berry Good HEART HEART': ['( ISHA', ', Sehyung', ', Taeha', ')'],
#  'BESTie': ['( Dahye', ', U-JI', ', Haeryung', ', Hyeyeon', ')'],
#  'BEWAVE': ['( Gowoon',
#   ', Ain',
#   ', Lena',
#   ', Jiun',
#   ', Yunseul',
#   ', Zena',
#   ')'],
#  'BF': ['( Youngmin',
#   ', Minwoo',
#   ', Donghyun',
#   ', Kwangmin',
#   ', Hyunseong',
#   ', Jeongmin',
#   ')'],
#  'BGH4': ['( Misty', ')'],
#  'Big Mama': ['( Park Min Hye',
#   ', Lee Ji Young',
#   ', Lee Young Hyun',
#   ', Shin Yeon Ah',
#   ')'],
#  'BIGBANG': ['( G-Dragon',
#   ', T.O.P',
#   ', Taeyang',
#   ', Daesung',
#   ', Seungri',
#   ')'],
#  'BIGFLO': ['( Euijin',
#   ', Ron',
#   ', Z-uK',
#   ', Kichun',
#   ', Lex',
#   ', Sungmin',
#   ', Jeongkyun',
#   ', Hyuntae',
#   ', Eden',
#   ')'],
#  'BIGSTAR': ['( Feeldog', ', From20', ', Jude', ', Amón', ', Sunghak', ')'],
#  'Bijou': ['( Jumin', ')'],
#  'BIKINY': ['( Mizi',
#   ', Yoa',
#   ', Haei',
#   ', Dami',
#   ', UZ',
#   ', LaLa',
#   ', Jaein',
#   ')'],
#  'Billlie': ['( Tsuki',
#   ', Suhyeon',
#   ', Moon Sua',
#   ', Sheon',
#   ', Haram',
#   ', Haruna',
#   ', Siyoon',
#   ')'],
#  'Black Bunny': ['( Mimi', ', Daya', ', Eve', ', SuA', ')'],
#  'Black Eye': ['( Taegyeong', ', Dain', ')'],
#  'Black Level': ['( Jongwoo',
#   ', Uin',
#   ', Younghoon',
#   ', Intae',
#   ', Siwoo',
#   ', TaeYoung',
#   ')'],
#  'Black Pearl': ['( Nami',
#   ', Mikka',
#   ', Hwieun',
#   ', Youngjoo',
#   ', Jungmin',
#   ')'],
#  'Black Swan': ['( Mimi', ', Sumin', ', Haneul', ', Seo Yoon Mi', ')'],
#  'BLACK6IX': ['( Dam',
#   ', Yongseok',
#   ', The King',
#   ', Yey',
#   ', Ziki',
#   ', Jongwoon',
#   ')'],
#  'Blacklist': ['( Cheetah', ', Lucy', ')'],
#  'BLACKPINK': ['( Lisa', ', Jisoo', ', Jennie', ', Rosé', ')'],
#  'BLACKSWAN': ['( Fatou',
#   ', Youngheun',
#   ', Gabi',
#   ', Judy',
#   ', Sriya',
#   ', Leia',
#   ', Hyeme',
#   ', NVee',
#   ')'],
#  'Blady': ['( Tina',
#   ', Sunyoung',
#   ', Iro',
#   ', CoCo',
#   ', Nahyun',
#   ', Soojin',
#   ', Kangyoon',
#   ', Bunhong',
#   ', Lilty',
#   ', Yeeun',
#   ', Giru',
#   ', Dayoung',
#   ', Ryeowon',
#   ')'],
#  'Blah Blah': ['( Hyoin',
#   ', Hajung',
#   ', Jiwoo',
#   ', Eunyuri',
#   ', Seolhwa',
#   ')'],
#  'BLANC7': ['( Spax',
#   ', Taichi',
#   ', D.L',
#   ', K-KID',
#   ', Shinwoo',
#   ', Teno',
#   ', Jean Paul',
#   ')'],
#  'BLANK2Y': ['( Mikey',
#   ', Sodam',
#   ', Sungjun',
#   ', Donghyuk',
#   ', Louis',
#   ', Dokyun',
#   ', Siwoo',
#   ', Youngbin',
#   ', U',
#   ')'],
#  'Blastar': ['( Donga', ', Seowoo', ', On', ', Gahee', ', Jinsil', ')'],
#  'BLAZE': ['( Hayun', ', Saeha', ', Haena', ')'],
#  'BLE': ['( Hyuna', ', Seonah', ', Hyoin', ')'],
#  'BLINDZ': ['( Yubeen', ', Soyeon', ', Jiyoung', ')'],
#  'Bling': ['( Mint',
#   ', Gaon',
#   ', Sia',
#   ', Shinwoo',
#   ', Seohyang',
#   ', Rian',
#   ')'],
#  'Bling Bling': ['( Yubin',
#   ', Narin',
#   ', Ayamy',
#   ', Marin',
#   ', Juhyun',
#   ', Jieun',
#   ')'],
#  'Blity': ['( Say', ', Won', ', Joah', ', Seeya', ')'],
#  'BLITZERS': ['( Chris',
#   ', Wooju',
#   ', Go_U',
#   ', Jinhwa',
#   ', Lutan',
#   ', Sya',
#   ', Juhan',
#   ')'],
#  'BLK': ['( Ming Ming', ', Hyeonsu', ', Taebin', ', Ilkyoung', ')'],
#  'Block B': ['( Zico',
#   ', U-Kwon',
#   ', P.O.',
#   ', Taeil',
#   ', B-Bomb',
#   ', Kyung',
#   ', Jaehyo',
#   ')'],
#  'Bloomy': ['( Daru', ', Yeonji', ', Seoyeon', ', E.DA', ')'],
#  'Blue Fox': ['( GARD€N',
#   ', Aria',
#   ', Yousi',
#   ', Jin Dozin',
#   ', Youzin',
#   ', Yeonji',
#   ', Jenny',
#   ', Ayeon',
#   ', Moon',
#   ', Jina Son',
#   ', Doyeon',
#   ', Hyogang',
#   ', Haena',
#   ')'],
#  'BNF': ['( Ha Bin', ', Harang', ', Daewon', ')'],
#  'Bob Girls': ['( Jaina', ', Heo Yu Jeong', ', Nadanbi', ', Migyo', ')'],
#  'Bolbbalgan4': ['( Jiyoung', ', Jiyoon', ')'],
#  'BOM&HI': ['( Lee Hi', ', Park Bom', ')'],
#  'BONUSbaby': ['( Choi Moon Hee',
#   ', Kongyoo',
#   ', Gaon',
#   ', Chaehyun',
#   ', Dayun',
#   ', Hayoon',
#   ')'],
#  'BOTOPASS': ['( Mihee',
#   ', Seoyoon',
#   ', Harin',
#   ', Ria',
#   ', Subin',
#   ', Cui Xiang',
#   ', Ahyoon',
#   ', Jiwon',
#   ')'],
#  'BOY STORY': ['( Xinlong',
#   ', Zeyu',
#   ', Shuyang',
#   ', Zihao',
#   ', Hanyu',
#   ', Mingrui',
#   ')'],
#  'BOYNEXTDOOR': ['( Woonhak',
#   ', Jaehyun',
#   ', Leehan',
#   ', Sungho',
#   ', Taesan',
#   ', Riwoo',
#   ')'],
#  'Boys Republic': ['( Minsu',
#   ', Suwoong',
#   ', Sungjun',
#   ', Onejunn',
#   ', Sunwoo',
#   ')'],
#  'BP POP': ['( Pyeon Ji', ', Yoojin', ', In Kyung', ', CU', ', Jane', ')'],
#  'Brand New Day': ['( Soo Ji', ', Geum Dan Bi', ', Chae Rin', ')'],
#  'Broccoli, you too': ['( Hyunho',
#   ', Gyepy',
#   ', Hyanggi',
#   ', Ryuji',
#   ', Jandi',
#   ', Deokwon',
#   ')'],
#  'Brown Eyed Girls': ['( Gain', ', Narsha', ', Miryo', ', JeA', ')'],
#  'BSS': ['( Hoshi', ', DK', ', Seungkwan', ')'],
#  'BT Swing': ['( Baby Kimi', ', J.Bin', ', H.Hyun', ', Xing Na', ')'],
#  'BTOB': ['( Minhyuk',
#   ', Peniel',
#   ', Sungjae',
#   ', Eunkwang',
#   ', Ilhoon',
#   ', Hyunsik',
#   ', Changsub',
#   ')'],
#  'BTOB 4U': ['( Minhyuk', ', Peniel', ', Eunkwang', ', Changsub', ')'],
#  'BTOB-BLUE': ['( Sungjae', ', Eunkwang', ', Hyunsik', ', Changsub', ')'],
#  'BTS': ['( V',
#   ', Jungkook',
#   ', SUGA',
#   ', Jimin',
#   ', RM',
#   ', j-hope',
#   ', Jin',
#   ')'],
#  'Bubble X': ['( Hyejin', ', Daae', ', Juha', ')'],
#  'bugAboo': ['( Choyeon',
#   ', Rainie',
#   ', Zin',
#   ', Eunchae',
#   ', Yoona',
#   ', Cyan',
#   ')'],
#  'Bulldok': ['( Kimi', ', Hyungeun', ', Say', ', Sora', ', Genie', ')'],
#  'Bunny.T': ['( Nina', ', Eun A', ', Ji Young', ', Cheong Eum', ')'],
#  'Burvey': ['( Seoyoon',
#   ', Yooran',
#   ', Yerin',
#   ', Seoyeon',
#   ', Zia',
#   ', Chaewon',
#   ', Youyi',
#   ', Jiwoo',
#   ')'],
#  'Busker Busker': ['( Brad', ', Kim Hyung Tae', ', Jang Beom June', ')'],
#  'Busters': ['( Yeseo',
#   ', Kim Chaeyeon',
#   ', Hyungseo',
#   ', Takara',
#   ', Jieun',
#   ', Jeong Jisoo',
#   ', Minji',
#   ', Minjung',
#   ', Yunji',
#   ', MinMin',
#   ', Minji',
#   ', Nami',
#   ', Seira',
#   ', U-Min',
#   ')'],
#  'BUZZ': ['( Kyunghoon', ', Junki', ', Sunghee', ', Woohyun', ', Yejun', ')'],
#  'BVNDIT': ['( Jungwoo',
#   ', Seungeun',
#   ', Simyeong',
#   ', Yiyeon',
#   ', Songhee',
#   ')'],
#  'BXB': ['( Jihun', ', Hamin', ', Siwoo', ', June', ', Hyunwoo', ')'],
#  'Byulzzi': ['( Jihye', ', Harin', ', Yongchae', ')'],
#  'BZ-Boys': ['( Seunghyun',
#   ', Hamin',
#   ', Bon',
#   ', Double.D',
#   ', Taewoong',
#   ')']}

# %%
# further cleaning the alphabetically ordered dictionary
for key, val in normal_char_idol.items():
    for inner_key, list_of_strings in val.items():
        updated_list = []  # Create a new list to hold updated strings
        for word in list_of_strings:
            # Remove the characters `(`, `)`, and `,`
            updated_word = re.sub(r'[\(\), ]', '', word)
            # Only add non-empty strings to the updated list
            if updated_word != '':
                updated_list.append(updated_word)
        # Update the dictionary with the cleaned list
        normal_char_idol[key][inner_key] = updated_list

# %%
# further cleaning the special charactered dictionary
for key, val in special_char_idol.items():
    for inner_key, list_of_strings in val.items():
        updated_list = []  # Create a new list to hold updated strings
        for word in list_of_strings:
            # Remove the characters `(`, `)`, and `,`
            updated_word = re.sub(r'[\(\), ]', '', word)
            # Only add non-empty strings to the updated list
            if updated_word != '':
                updated_list.append(updated_word)
        # Update the dictionary with the cleaned list
        special_char_idol[key][inner_key] = updated_list

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = 'drive/MyDrive/Colab Notebooks/kpop trend analysis/dataset_raw'
os.path.exists(path)
# Out:
# True

# %% [markdown]
# ##Finally, storing them as JSON

# %%
# Open a new file in write mode
with open(os.path.join(path,'normal_char_idol.json'), 'w') as file:
    # Use json.dump() to write the dictionary to the file
    json.dump(normal_char_idol, file, indent=4)

# %%
# Open a new file in write mode
with open(os.path.join(path,'special_char_idol.json'), 'w') as file:
    # Use json.dump() to write the dictionary to the file
    json.dump(special_char_idol, file, indent=4)
